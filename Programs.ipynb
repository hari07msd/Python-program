# %% [markdown]
# <a href="https://colab.research.google.com/github/hari07msd/Python-program/blob/main/Programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. print welcome
print("Welcome")
# Out:
# Welcome

# %%
# 2. print a given word
w=input("Ënter the word:")
print(w)
# Out:
# Ënter the word:hi
# hi

# %%
# 3.print the given message
print("Hello World")
# Out:
# Hello World

# %%
# 4.print a given integer
a= 12
print(a)
# Out:
# 12

# %%
# 5.print a given fractional number
from fractions import Fraction
f =Fraction(4,5)
print(f)
# Out:
# 4/5

# %%
# 6.print the given fractional number in 2 digit decimal format
n=6.534753
print(f"{n:.2f}")
# Out:
# 6.53

# %%
# 7.print given integer number in Hexadecimal format.
dn=266
print(hex(dn))
dn=0x2b
print(dn)
# Out:
# 0x10a
# 43

# %%
# 8.print given integer number in octal format.
n=40
print(oct(n))
n=0o40
print(n)
# Out:
# 0o50
# 32

# %%
# 9.print given hexadecimal number in integer format.
n=24
print(hex(n))
n=0x24
print(n)
# Out:
# 0x18
# 36

# %%
# 10.print given octal number in integer format.
n=0o77
print(n)
n=63
print(oct(n))
# Out:
# 63
# 0o77

# %%
# 11.print the ASCII value of a character.
char = "H"
ascii_value = ord(char)
print(ascii_value)
# Out:
# 72

# %%
# Q12. Print the character for given ASCII value

ascii_value = 65
character = chr(ascii_value)
print(character)
# Out:
# A

# %%
# Q13. Print two numbers with a space between them

a = 10
b = 20
print(a, b)
# Out:
# 10 20

# %%
# Q14. Print two numbers with a tab space between them

a = 10
b = 20
print(a, "\t", b)
# Out:
# 10 	 20

# %%
# Q15. Print two numbers in two lines

a = 10
b = 20
print(a)
print(b)
# Out:
# 10
# 20

# %%
# Q16. Print a character in single quotes

char = 'H'
print("'" + char + "'")
# Out:
# 'H'

# %%
# Q17. Print two words in double quotes

word1 = "Hello"
word2 = "World"
print(f'"{word1}" "{word2}"')
# Out:
# "Hello" "World"

# %%
# Q18. Print your date of birth in the format DD/MM/YYYY

dob = "21/11/2005"
print(dob)
# Out:
# 21/11/2005

# %%
# Q19. Print an integer with a plus sign (+) before it

num = 69
print(f"+{num}")
# Out:
# +69

# %%
# Q20. Print the size of char, int, float and double

import sys
char = 'H'
integer = 20
float_num = 30.5
double_num = 40.7777777
print("Size of char:", sys.getsizeof(char), "bytes")
print("Size of int:", sys.getsizeof(integer), "bytes")
print("Size of float:", sys.getsizeof(float_num), "bytes")
print("Size of double:", sys.getsizeof(double_num), "bytes")
# Out:
# Size of char: 42 bytes
# Size of int: 28 bytes
# Size of float: 24 bytes
# Size of double: 24 bytes

# %%
# Q21. Print roll number and name

roll_no = 120
name = "Hari"
print(f"Roll No: {roll_no}, Name: {name}")
# Out:
# Roll No: 120, Name: Hari

# %%
# Q22. Print marks in 5 subjects each on a new line

maths = 95
science = 97
english = 94
social = 96
computer = 98

print("Maths:", maths)
print("Science:", science)
print("English:", english)
print("Social:", social)
print("Computer:", computer)
# Out:
# Maths: 95
# Science: 97
# English: 94
# Social: 96
# Computer: 98

# %%
# Q23. Print your blood group

blood_group = "O+"
print("Blood Group:", blood_group)
# Out:
# Blood Group: O+

# %%
# Q24. Print current time in the format HH:MM:SS

from datetime import datetime
current_time = datetime.now().strftime("%H:%M:%S")
print(current_time)
# Out:
# 04:56:24

# %%
# Q25. Print your address in multiple lines

print("H-99, Karpagam College")
print("Coimbatore")
print("Tamil Nadu")
print("India")
# Out:
# H-99, Karpagam College
# Coimbatore
# Tamil Nadu
# India
